# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
housedf=pd.read_csv('NY-House-Dataset.csv')
housedf
# Out:
#                                             BROKERTITLE                TYPE  \
# 0           Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                   Brokered by Serhant      Condo for sale
# 2                                Brokered by Sowae Corp      House for sale
# 3                                   Brokered by COMPASS      Condo for sale
# 4     Brokered by Sotheby's International Realty - E...  Townhouse for sale
# ...                                                 ...                 ...
# 4796                                Brokered by COMPASS      Co-op for sale
# 4797                    Brokered by Mjr Real Estate Llc      Co-op for sale
# 4798      Brokered by Douglas Elliman - 575 Madison Ave      Co-op for sale
# 4799            Brokered by E Realty International Corp      Condo for sale
# 4800                 Brokered by Nyc Realty Brokers Llc      Co-op for sale
#
#           PRICE  BEDS       BATH  PROPERTYSQFT  \
# ...

# %%
housedf.isnull().sum()
# Out:
# BROKERTITLE                    0
# TYPE                           0
# PRICE                          0
# BEDS                           0
# BATH                           0
# PROPERTYSQFT                   0
# ADDRESS                        0
# STATE                          0
# MAIN_ADDRESS                   0
# ADMINISTRATIVE_AREA_LEVEL_2    0
# LOCALITY                       0
# SUBLOCALITY                    0
# STREET_NAME                    0
# LONG_NAME                      0
# FORMATTED_ADDRESS              0
# LATITUDE                       0
# LONGITUDE                      0
# dtype: int64

# %%
housedf['BROKERTITLE'].unique()
# Out:
# array(['Brokered by Douglas Elliman  -111 Fifth Ave',
#        'Brokered by Serhant', 'Brokered by Sowae Corp', ...,
#        'Brokered by Fine Choice Realty Inc',
#        'Brokered by Silverside Realty LLC',
#        'Brokered by New York Way Real Estate Corp'], dtype=object)

# %%
housedf['TYPE'].unique()
# Out:
# array(['Condo for sale', 'House for sale', 'Townhouse for sale',
#        'Co-op for sale', 'Multi-family home for sale', 'For sale',
#        'Contingent', 'Land for sale', 'Foreclosure', 'Pending',
#        'Coming Soon', 'Mobile house for sale', 'Condop for sale'],
#       dtype=object)

# %%
housedf['ADMINISTRATIVE_AREA_LEVEL_2'].unique()
# Out:
# array(['New York County', 'United States', 'New York', 'Bronx County',
#        '11214', '10301', '10309', '10303', '11234', '11414', '10310',
#        '10003', '11417', '10304', 'Kings County', '10463',
#        'Queens County', '10017', '10306', '10471', '11229', '10312',
#        '11412', '10465', 'Brooklyn', '10002', '10466', '11237', '11218'],
#       dtype=object)

# %%
housedf['SUBLOCALITY'].unique()
# Out:
# array(['Manhattan', 'New York County', 'Richmond County', 'Kings County',
#        'New York', 'East Bronx', 'Brooklyn', 'The Bronx', 'Queens',
#        'Staten Island', 'Queens County', 'Bronx County', 'Coney Island',
#        'Brooklyn Heights', 'Jackson Heights', 'Riverdale', 'Rego Park',
#        'Fort Hamilton', 'Flushing', 'Dumbo', 'Snyder Avenue'],
#       dtype=object)

# %%
housedf=housedf.drop(columns=['BROKERTITLE','ADDRESS','STATE','MAIN_ADDRESS','ADMINISTRATIVE_AREA_LEVEL_2','STREET_NAME','LONG_NAME','FORMATTED_ADDRESS','LATITUDE','LONGITUDE','LOCALITY','SUBLOCALITY'])

# %%
housedf
# Out:
#                     TYPE      PRICE  BEDS       BATH  PROPERTYSQFT
# 0         Condo for sale     315000     2   2.000000   1400.000000
# 1         Condo for sale  195000000     7  10.000000  17545.000000
# 2         House for sale     260000     4   2.000000   2015.000000
# 3         Condo for sale      69000     3   1.000000    445.000000
# 4     Townhouse for sale   55000000     7   2.373861  14175.000000
# ...                  ...        ...   ...        ...           ...
# 4796      Co-op for sale     599000     1   1.000000   2184.207862
# 4797      Co-op for sale     245000     1   1.000000   2184.207862
# 4798      Co-op for sale    1275000     1   1.000000   2184.207862
# 4799      Condo for sale     598125     2   1.000000    655.000000
# 4800      Co-op for sale     349000     1   1.000000    750.000000
#
# [4801 rows x 5 columns]

# %%
housedf=pd.get_dummies(housedf,dtype=int)

# %%
housedf
# Out:
#           PRICE  BEDS       BATH  PROPERTYSQFT  TYPE_Co-op for sale  \
# 0        315000     2   2.000000   1400.000000                    0
# 1     195000000     7  10.000000  17545.000000                    0
# 2        260000     4   2.000000   2015.000000                    0
# 3         69000     3   1.000000    445.000000                    0
# 4      55000000     7   2.373861  14175.000000                    0
# ...         ...   ...        ...           ...                  ...
# 4796     599000     1   1.000000   2184.207862                    1
# 4797     245000     1   1.000000   2184.207862                    1
# 4798    1275000     1   1.000000   2184.207862                    1
# 4799     598125     2   1.000000    655.000000                    0
# 4800     349000     1   1.000000    750.000000                    1
#
#       TYPE_Coming Soon  TYPE_Condo for sale  TYPE_Condop for sale  \
# 0                    0                    1                     0
# ...

# %%
x=housedf.drop(columns=['PRICE'])
y=housedf['PRICE']
y
# Out:
# 0          315000
# 1       195000000
# 2          260000
# 3           69000
# 4        55000000
#           ...
# 4796       599000
# 4797       245000
# 4798      1275000
# 4799       598125
# 4800       349000
# Name: PRICE, Length: 4801, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
LinModel=LinearRegression()
LinModel.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
LinModel.predict(x_test)
# Out:
# array([ 4.82306451e+06,  3.60596862e+06,  3.93281764e+06,  7.50974145e+05,
#         9.64604148e+05,  3.76114586e+06,  1.58586656e+06,  4.99180449e+06,
#        -1.92899450e+06,  3.58537194e+05,  2.87107243e+06,  1.22812675e+06,
#         6.07549497e+06,  4.95821271e+07,  1.68292715e+06,  7.85241766e+05,
#        -3.39423718e+05,  4.88777477e+06,  8.38150024e+05, -7.07996219e+05,
#        -6.14732236e+05,  8.12912560e+05,  1.06506112e+06, -1.25939696e+06,
#         2.30252167e+06,  5.69540300e+06,  3.96227439e+06,  1.96720253e+06,
#         7.94559744e+05,  6.64780905e+05, -1.72980993e+06,  1.41375323e+07,
#         1.99253907e+06,  9.24384539e+06,  1.44740762e+06,  1.29936932e+06,
#         2.64944530e+06,  3.64854226e+06,  2.83639835e+06,  4.51244095e+06,
#         2.35666189e+07, -7.86686125e+05,  3.31286222e+05, -1.56896734e+06,
#         5.28041757e+06,  9.35529995e+06,  1.93242505e+06,  1.53939948e+07,
# ...

# %%
LinModel.score(x_test,y_test)
# Out:
# -0.6477063854469767

# %%
LinModel.score(x_train,y_train)
# Out:
# 0.01662493048785929

# %%
from sklearn.linear_model import Lasso

# %%
LasModel=Lasso(alpha=25,max_iter=150,tol=0.5)
LasModel.fit(x_train,y_train)
# Out:
# Lasso(alpha=25, max_iter=150, tol=0.5)

# %%
LasModel.predict(x_test)
# Out:
# array([ 4.61836651e+06,  3.83576480e+06,  3.45418222e+06,  9.26963597e+05,
#         5.22088453e+06,  3.90483687e+06,  2.13416652e+06,  4.86888098e+06,
#        -1.46129771e+06, -7.00212991e+05,  2.35083907e+06,  5.95606602e+05,
#         6.31395528e+06,  4.89276958e+07,  1.61707922e+06,  3.30426832e+06,
#        -1.83590983e+05,  4.90796997e+06,  2.18238023e+06, -9.75589804e+05,
#        -8.92548984e+05,  1.68183384e+05, -7.44002566e+04, -1.18924481e+06,
#         2.77226524e+06,  5.30292329e+06,  3.48041006e+06,  1.40636613e+06,
#         9.18928836e+05,  6.63694702e+05, -9.57742027e+05,  1.35185997e+07,
#         1.72658795e+06,  9.50937928e+06,  1.50021458e+06, -1.62760060e+05,
#         2.52026359e+06,  3.66489530e+06,  2.01411978e+06,  3.76744010e+06,
#         2.23352659e+07, -1.15767937e+06,  5.53279907e+05, -2.06839009e+06,
#         5.95324169e+06,  1.04412605e+07,  2.34566727e+06,  1.60730729e+07,
# ...

# %%
LasModel.score(x_test,y_test)
# Out:
# -0.5805940137899044

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DecModel=DecisionTreeClassifier()
DecModel.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
DecModel.predict(x_test)
# Out:
# array([ 3200000,   350000,   550000,   375000,   999000,   499000,
#         2000000,  4950000,   799000,   478888,   330000,  1080000,
#         5925000, 28500000,   279000,   899000,   519000,  1688888,
#         2200000,   165000,   175000,   790000,   375000,   899975,
#          399000,  1288000,   669000,   225000,  2280000,  2350000,
#          140000, 23000000,   598000,  3850000,  1399000,  1348888,
#         3250000,   709999,   630000,   500000, 24950000,   299998,
#         1950000,   250000,  1299999, 10900000,   434900,  2599999,
#         2250000,   205000,   698999,   650000,  1950000,   550000,
#          550000,   750000,   699900,   165000,   175000,   375000,
#          349000,   279000,   650000,   550000,   275000,  3250000,
#          799000,   449000,  1950000,   279000,   879000,   245000,
#          928000,   825000,   110000,  1389000,   625000,   225000,
#           99000,   685000, 12995000,  1188000,   879000,   225000,
# ...

# %%
DecModel.score(x_test,y_test)
# Out:
# 0.05619146722164412

# %%
DecModel.score(x_train,y_train)
# Out:
# 0.61640625

# %%
from sklearn.linear_model import LogisticRegression

# %%
LogModel=LogisticRegression()
LogModel.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
LogModel.predict(x_test)
# Out:
# array([1250000, 1250000, 1250000, 1250000, 1250000, 1250000, 1250000,
#        1250000, 1250000, 1250000, 1250000, 1250000, 1250000, 1250000,
#        1250000, 1250000, 1250000, 1250000, 1250000, 1250000, 1250000,
#        1250000, 1250000, 1250000, 1250000, 1250000, 1250000, 1250000,
#        1250000, 1250000, 1250000, 1250000, 1250000, 1250000, 1250000,
#        1250000, 1250000, 1250000, 1250000, 1250000, 1250000, 1250000,
#        1250000, 1250000, 1250000, 1250000, 1250000, 1250000, 1250000,
#        1250000, 1250000, 1250000, 1250000, 1250000, 1250000, 1250000,
#        1250000, 1250000, 1250000, 1250000, 1250000, 1250000, 1250000,
#        1250000, 1250000, 1250000, 1250000, 1250000, 1250000, 1250000,
#        1250000, 1250000, 1250000, 1250000, 1250000, 1250000, 1250000,
#        1250000, 1250000, 1250000, 1250000, 1250000, 1250000, 1250000,
#        1250000, 1250000, 1250000, 1250000, 1250000, 1250000, 1250000,
# ...

# %%
LogModel.score(x_test,y_test)
# Out:
# 0.009365244536940686

# %%
LogModel.score(x_train,y_train)
# Out:
# 0.00859375
